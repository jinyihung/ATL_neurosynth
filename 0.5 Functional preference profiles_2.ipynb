# %% [markdown]
# ## Functional preference profiles
#
# For each region in the clustering analysis, we're going to determine how well we can classify studies that activated the region, versus those that did not, on the basis of semantic topics that describe the psychological states in each study.
#
# Using the RegionalClassifier class included in this repo, we can perform this analysis on any given clustering image. I've also included some functons to easily make polar plots to visualize which topics were most strongly associated with any given region

# %% [markdown]
# ### Classification

# %%
# %matplotlib inline
from neurosynth.base.dataset import Dataset
dataset = Dataset.load("data/neurosynth_0.6_400_4.pkl")
from sklearn.naive_bayes import GaussianNB
from classification import RegionalClassifier
from plotting import plot_clf_polar
from sklearn.metrics import roc_auc_score
from nilearn import plotting as niplt
import seaborn as sns
from matplotlib.colors import ListedColormap
import numpy as np
import pandas as pd

# %% [markdown]
# We used Gaussian naive Bayes for classificaiton, and extract log odds ratios for each topic for each region to estimate how strongly each psychological state indicated that a given region was active.

# %%
# Instantiate a RegionalClassifier for your image and classify
wclf60 = RegionalClassifier(dataset, 'images/wATL/whole60_k4.nii', GaussianNB())
wclf60.classify(scoring=roc_auc_score)
# Out:
# Classifying...
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# [##########] 100%
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /mnt/c/Users/user/neurosynth-lfc-master/venv/local/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %%
wclf60.class_score
# Out:
# array([ 0.61315421,  0.58845043,  0.63749027,  0.56469709])

# %% [markdown]
# We can take a look at various aspects of the classification performance such as the classification performance for each region (in this case ROC area under the curve):

# %% [markdown]
# ### Visualization with polar plots
#
# #### Note that I ended up using wordclouds in r for visulaization in the manuscript. I presented the feature words (instead of a topic name I assigned) based on their LOR values and the permutation results.
#
# The original thought, following de la Vega (2016, 2018) was plotted below. I separated the dorsal and ventral clusters and plotted them based on their most associated topics.

# %% [markdown]
# We've included a listing of the topics used in the manuscript, and a set of "nicknames" that we used throughout the manuscript for each topic. This bit of code extracts the nickname (i.e. topic_name) I gave to each topic to help with visualization. You may also use "top_2" to label each topic with the two strongest loading words.

# %%
word_keys = pd.read_csv("data/v4-topics-400.txt", delimiter='\t')
word_keys['top_2'] = word_keys['top_words'].apply(lambda x: x.split(' ')[0] + ' ' + x.split(' ')[1])
word_keys['topic_name'] = word_keys.apply(lambda row: '_'.join([str(row.topic_number)] + row.top_words.split(' ')[0:3]), axis=1)
feature_names2 = pd.merge(pd.DataFrame(wclf60.feature_names, columns=['topic_name']), word_keys)['nickname'].tolist()

# %% [markdown]
# To recreate the plots from the publication, we simply extract a pandas formatted table of importances that represent how strongly each topic indicated each region would be active in a study (in this case log odds ratios) using `clf.get_formatted_importances`, ensuring to provide the topic nicknames from above.
#
# Then, we feed this pandas table into plot_clf_polar, which returns a nice polar plot each each prespecified topic.

# %%
from plotting import plot_clf_polar

# %%
selected_labels = ['auditory', 'voice identity', 'speech', 'music', 'visuoauditory modality', 'language', 'phonological', 'sentence', 'comprehension', 'verbal fluency', 'empathy', 'ToM', 'social cognition', 'mentalization', 'semantics', 'events', 'abstract concrete', 'referential judgment', 'gesture communication', 'DMN', 'memory retrieval', 'memory encoding', 'recognition', 'recollection', 'facial expression', 'face', 'face_emo', 'picture', 'valence', 'emotion regulation', 'emotioal proc', 'fear conditioning', 'threat']

dorsal_labels = ['auditory', 'voice identity', 'speech', 'music', 'visuoauditory modality', 'language', 'phonological', 'sentence', 'comprehension', 'verbal fluency', 'semantics', 'memory retrieval', 'face_emo', 'picture', 'emotion regulation', 'emotioal proc']

ventral_labels = ['speech', 'sentence', 'comprehension', 'empathy', 'ToM', 'social cognition', 'mentalization', 'semantics', 'events', 'abstract concrete', 'referential judgment', 'gesture communication', 'DMN', 'memory retrieval', 'memory encoding', 'recognition', 'recollection', 'facial expression', 'face', 'face_emo', 'picture', 'valence', 'emotion regulation', 'emotioal proc', 'fear conditioning', 'threat']

# %% [markdown]
# ### Functional profiles for the whole ATL (K =4)

# %% [markdown]
# Ventral (red)
# dorsal_inf (green)
# Para (orange)
# dorsal_sup (grey)

# %%
dorsal = [2,4]
ventral = [1,3]

# %%
formated_importances = wclf60.get_formatted_importances(feature_names=feature_names2)

colors = ['magenta', 'green', 'orange', 'grey']
colors = sns.xkcd_palette(colors)

sem = plot_clf_polar(formated_importances,labels = selected_labels, palette = colors,label_size=14, max_val=2.2)
dorsal = plot_clf_polar(formated_importances,labels = dorsal_labels, mask = dorsal, palette = colors,label_size=14, max_val=2.2)
ventral = plot_clf_polar(formated_importances,labels = ventral_labels, mask = ventral, palette = colors,label_size=14, max_val=2.2)

# %% [markdown]
# Alternatively, asking plot_clf_polar to choose some topics for us. In this case, we're asking for the 6 topics that load most strongly for each region, and specifiying that these topics are reordered to ensure a nice looking visualization. Under the hood, this function uses hierarchical clustering to reorder the topics. See the docstring of plot_polar for many more ways to choose topics and automatically order the features.

# %%
colors = ['magenta',"green",'orange', "grey"]
colors = sns.xkcd_palette(colors)

topics =plot_clf_polar(wclf60.get_formatted_importances(feature_names=feature_names2), n_top=6, reorder=True, max_val=2.5, label_size=16, palette = colors)

# %% [markdown]
# plot_clf_polar also returns the topics it selected as a list, and the data that went into the visualization (for debugging)

# %%
topics
# Out:
# (['verbal fluency',
#   'ambiguity',
#   'auditory',
#   'speech',
#   'voice identity',
#   'music',
#   'phonological',
#   'fear conditioning',
#   'face_emo',
#   'olfactory',
#   'picture',
#   'recollection',
#   'events',
#   'memory retrieval',
#   'humor',
#   'comprehension',
#   'gesture communication',
#   'mentalization'],
#  region                        1         2         3         4
#  feature
#  verbal fluency         0.034484  0.265848 -0.330537  0.729327
#  ambiguity              0.121575  0.898990  0.037292  0.744134
#  auditory              -0.381749  1.511362 -1.164753  0.412593
#  speech                 0.779967  1.868153 -1.319389  0.676713
#  voice identity         0.951728  2.041383 -1.096714  0.598984
#  music                  0.446160  1.501197 -0.715279  1.212236
#  phonological           0.248620  0.807382 -0.673291  0.704344
#  fear conditioning     -1.522135 -0.167692  1.562245  0.213589
#  face_emo               0.093677 -0.089874  1.504895  0.168890
#  olfactory             -0.047105 -0.365170  1.917270  0.684050
#  picture                0.031629  0.043027  1.358495  0.508883
#  recollection           1.036573 -0.126945  1.265792  0.034294
#  events                 2.359802  0.888406  1.495641 -0.036764
#  memory retrieval       1.274363  0.588472  1.103667  0.294080
#  humor                  1.462470  1.469144  0.964708  0.540074
#  comprehension          1.804012  1.402224 -0.524356  0.821245
#  gesture communication  1.555643  0.528801 -0.028752  0.315151
#  mentalization          1.386523  0.285795  0.140177  0.059209,
#  <matplotlib.figure.Figure at 0x7f8e71aa0450>)

# %% [markdown]
# # Estimate uncertainty
#
# ## Permutation tests

# %% [markdown]
# First, using permute_log_odds_ratio we perform a permutation test for each region - topic log odds ratio, resulting in the z-score and p-value of the observed log odds ratio in permuted null distribution. Small p-values indicate it is inprobably we would observe the given log odds ratio under the null distribution.
# Note that this function takes a fitted RegionalClassifier model (that we generated above) and the number of times to resample as required arguments

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport classification

# %%
# These are the names of each region in the left ATL
whole_ATL = ['ventral', 'dorsal-inf','para', 'dorsal-sup']

# %%
from classification import permute_log_odds
lor_z = classification.permute_log_odds(wclf60, 1000, feature_names=None, region_names = whole_ATL)
# Out:
# [##########] 100%

# %%
print(lor_z)
# Out:
#              ROI                                variable     lor_z  \
# 0        ventral             0_patients_controls_healthy -0.157446
# 1     dorsal-inf             0_patients_controls_healthy -0.322177
# 2           para             0_patients_controls_healthy  1.728490
# 3     dorsal-sup             0_patients_controls_healthy  0.568708
# 4        ventral            100_smokers_smoking_nicotine -4.425109
# 5     dorsal-inf            100_smokers_smoking_nicotine -2.563043
# 6           para            100_smokers_smoking_nicotine  1.890864
# 7     dorsal-sup            100_smokers_smoking_nicotine -4.774471
# 8        ventral            101_personality_traits_trait -0.585050
# 9     dorsal-inf            101_personality_traits_trait -1.631954
# 10          para            101_personality_traits_trait  0.455163
# 11    dorsal-sup            101_personality_traits_trait  1.802915
# 12       ventral       102_updating_tracking_information -1.361710
# 13    dorsal-inf       102_updating_tracking_information -0.052308
# 14          para       102_updating_tracking_information -2.321595
# 15    dorsal-sup       102_updating_tracking_information -0.601569
# 16       ventral  103_perception_discrimination_physical -0.346735
# 17    dorsal-inf  103_perception_discrimination_physical  1.740614
# 18          para  103_perception_discrimination_physical -3.012253
# 19    dorsal-sup  103_perception_discrimination_physical  0.451786
# 20       ventral           104_connectivity_model_causal -3.591819
# 21    dorsal-inf           104_connectivity_model_causal -2.669392
# 22          para           104_connectivity_model_causal -4.234878
# 23    dorsal-sup           104_connectivity_model_causal -1.513222
# 24       ventral                105_normal_subjects_poor -0.673472
# 25    dorsal-inf                105_normal_subjects_poor -0.439263
# 26          para                105_normal_subjects_poor -1.852670
# 27    dorsal-sup                105_normal_subjects_poor -0.321140
# 28       ventral                   106_deaf_hearing_sign  0.214745
# 29    dorsal-inf                   106_deaf_hearing_sign  1.613649
# ...          ...                                     ...       ...
# 1570        para       93_swallowing_tongue_sensorimotor -1.433154
# 1571  dorsal-sup       93_swallowing_tongue_sensorimotor  1.450554
# 1572     ventral          94_number_identified_including  0.361960
# 1573  dorsal-inf          94_number_identified_including  2.060800
# 1574        para          94_number_identified_including  1.136978
# 1575  dorsal-sup          94_number_identified_including  1.037569
# 1576     ventral             95_pictures_picture_neutral  0.243104
# 1577  dorsal-inf             95_pictures_picture_neutral  0.346673
# 1578        para             95_pictures_picture_neutral  5.427575
# 1579  dorsal-sup             95_pictures_picture_neutral  3.131987
# 1580     ventral          96_performance_task_activation -2.061000
# 1581  dorsal-inf          96_performance_task_activation -2.218985
# 1582        para          96_performance_task_activation -3.404607
# 1583  dorsal-sup          96_performance_task_activation  1.209265
# 1584     ventral                 97_childhood_life_girls -1.711459
# 1585  dorsal-inf                 97_childhood_life_girls -0.523182
# 1586        para                 97_childhood_life_girls -2.306189
# 1587  dorsal-sup                 97_childhood_life_girls  0.102941
# 1588     ventral            98_controls_compared_healthy -0.373115
# 1589  dorsal-inf            98_controls_compared_healthy -0.723667
# 1590        para            98_controls_compared_healthy  0.693193
# 1591  dorsal-sup            98_controls_compared_healthy  0.639291
# 1592     ventral                 99_abeta_amyloid_burden -0.799097
# 1593  dorsal-inf                 99_abeta_amyloid_burden -0.306951
# 1594        para                 99_abeta_amyloid_burden  1.266548
# 1595  dorsal-sup                 99_abeta_amyloid_burden  0.933366
# 1596     ventral          9_paradigm_correlates_previous  0.794714
# 1597  dorsal-inf          9_paradigm_correlates_previous  1.451996
# 1598        para          9_paradigm_correlates_previous  0.716963
# 1599  dorsal-sup          9_paradigm_correlates_previous  1.045633
#
#                  p
# 0     8.748931e-01
# 1     7.473188e-01
# 2     8.390032e-02
# 3     5.695544e-01
# 4     9.639370e-06
# 5     1.037593e-02
# 6     5.864256e-02
# 7     1.801802e-06
# 8     5.585138e-01
# 9     1.026891e-01
# 10    6.489923e-01
# 11    7.140164e-02
# 12    1.732896e-01
# 13    9.582836e-01
# 14    2.025473e-02
# 15    5.474611e-01
# 16    7.287903e-01
# 17    8.175129e-02
# 18    2.593162e-03
# 19    6.514234e-01
# 20    3.283782e-04
# 21    7.598871e-03
# 22    2.286758e-05
# 23    1.302234e-01
# 24    5.006472e-01
# 25    6.604709e-01
# 26    6.392969e-02
# 27    7.481043e-01
# 28    8.299660e-01
# 29    1.066036e-01
# ...            ...
# 1570  1.518139e-01
# 1571  1.469040e-01
# 1572  7.173822e-01
# 1573  3.932216e-02
# 1574  2.555475e-01
# 1575  2.994706e-01
# 1576  8.079246e-01
# 1577  7.288371e-01
# 1578  5.712477e-08
# 1579  1.736276e-03
# 1580  3.930303e-02
# 1581  2.648772e-02
# 1582  6.625930e-04
# 1583  2.265610e-01
# 1584  8.699648e-02
# 1585  6.008479e-01
# 1586  2.110008e-02
# 1587  9.180096e-01
# 1588  7.090630e-01
# 1589  4.692700e-01
# 1590  4.881885e-01
# 1591  5.226339e-01
# 1592  4.242344e-01
# 1593  7.588806e-01
# 1594  2.053171e-01
# 1595  3.506312e-01
# 1596  4.267797e-01
# 1597  1.465026e-01
# 1598  4.733972e-01
# 1599  2.957304e-01
#
# [1600 rows x 4 columns]

# %% [markdown]
# Next, we must adjust the p-values for multiple comparisons. To do so, we will use False Discovery Rate.
#
# Finally, we use multipletests from the stats models package to correct our p-values given an alpha of 0.01. We then consider the null hypothesis rejected if the adjusted p-value is less than 0.05 and the sign is positive (excluding less easily interpreted negative associations).

# %%
lor_z_all = lor_z

from statsmodels.sandbox.stats.multicomp import multipletests

reject, p_corr, a, a1 = multipletests(lor_z_all.p, alpha=0.01, method='fdr_tsbky')

lor_z_all['p_corr_01'] = p_corr # Adjusted p-value
lor_z_all['reject_01'] = (lor_z_all.p_corr_01<0.05) & (lor_z_all.lor_z > 0) # Was the null hypothesis rejected?

# %% [markdown]
# The resulting table includes the FDR corrected p-value for each region/topic combination, and if the null hypothesis has been rejected.

# %%
lor_z_all.head()
# Out:
#           ROI                      variable     lor_z         p  p_corr_01  \
# 0     ventral   0_patients_controls_healthy -0.157446  0.874893   0.878424
# 1  dorsal-inf   0_patients_controls_healthy -0.322177  0.747319   0.822214
# 2        para   0_patients_controls_healthy  1.728490  0.083900   0.248705
# 3  dorsal-sup   0_patients_controls_healthy  0.568708  0.569554   0.719915
# 4     ventral  100_smokers_smoking_nicotine -4.425109  0.000010   0.000282
#
#   reject_01
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False

# %% [markdown]
# ## Bootstrapped log odds ratios
# Finally, another form of determining the uncertainty in our observations is to calculate bootstrapped confidence intervals for our estimates of the log odds ratio for each topic for each region.
#
# We can do so using the function bootstrap_log_odds.

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport classification

whole_ATL = ['ventral', 'dorsal-inf','para', 'dorsal-sup']

lor_ci = classification.bootstrap_log_odds(wclf60, 100, feature_names=None, region_names = whole_ATL, n_jobs=7)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [##########] 100%

# %%
lor_ci.head()
# Out:
#        region                              topic_name     hi_ci    low_ci  \
# 0  dorsal-inf             0_patients_controls_healthy  0.250714 -0.378739
# 1  dorsal-inf            100_smokers_smoking_nicotine -0.136456 -1.457558
# 2  dorsal-inf            101_personality_traits_trait  0.043471 -1.151486
# 3  dorsal-inf       102_updating_tracking_information  0.397678 -0.546668
# 4  dorsal-inf  103_perception_discrimination_physical  0.479388 -0.079895
#
#        mean
# 0 -0.039417
# 1 -0.738354
# 2 -0.455823
# 3 -0.052469
# 4  0.206788
